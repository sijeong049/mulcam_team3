# %%
# 매크로 같이 한글열어서 pdf로 바꿔주는 코드

# %%
import os  # .path.join(), .listdir(), .chdir(), .getcwd() 등 사용

import win32com.client as win32  # 한/글 열 수 있는 모듈
import win32gui  # 창 숨기기 위한 모듈

os.chdir('C:/Users/leeso/TIL/Project/BOK_paper/minutes/')  # 예제 hwp파일이 있는 폴더로 이동
print(os.listdir())  # 파일목록 출력해보기. 없어도 무관

hwp = win32.gencache.EnsureDispatch('HWPFrame.HwpObject')  # 한/글 열기
hwnd = win32gui.FindWindow(None, '빈 문서 1 - 한글')  # 해당 윈도우의 핸들값 찾기

print(hwnd)  # 핸들값 출력해보기. 없어도 무관

win32gui.ShowWindow(hwnd, 0)  # 한/글 창을 숨겨줘. 0은 숨기기, 5는 보이기, 3은 풀스크린 등
hwp.RegisterModule('FilePathCheckDLL', 'FilePathCheckerModule')  # 보안모듈 적용

BASE_DIR = 'C:/Users/leeso/TIL/Project/BOK_paper/minutes/'  # 한/글은 파일 열거나 저장할 때 전체경로를 입력해야 하므로, os.path.join(BASE_DIR, i) 식으로 사용할 것
print(os.getcwd())  # 현재경로 출력. 없어도 무관
print(len(os.listdir()))  # 현재폴더 안에 있는 파일 갯수 출력

for i in os.listdir():  # 현재폴더 안에 있는 모든 파일을
    hwp.Open(os.path.join(BASE_DIR, i))  # 한/글로 열어서
    hwp.HAction.GetDefault('FileSaveAsPdf', hwp.HParameterSet.HFileOpenSave.HSet)  # PDF로 저장할 건데, 설정값은 아래와 같이.
    hwp.HParameterSet.HFileOpenSave.filename = os.path.join(BASE_DIR, i.replace('.hwp', '.pdf'))  # 확장자는 .pdf로,
    hwp.HParameterSet.HFileOpenSave.Format = 'PDF'  # 포맷은 PDF로(소문자 "pdf" 입력하면 오류 발생)
    hwp.HAction.Execute('FileSaveAsPdf', hwp.HParameterSet.HFileOpenSave.HSet)  # 위 설정값으로 실행해줘.

win32gui.ShowWindow(hwnd, 5)  # 다시 숨겼던 한/글 창을 보여주고,
hwp.XHwpDocuments.Close(isDirty=False)  # 열려있는 문서가 있다면 닫아줘(저장할지 물어보지 말고)
hwp.Quit()  # 한/글 종료
# Out:
# ['금융통화위원회 의사록(2012년도 제6차)(2012.3.22).hwp', '금융통화위원회 의사록(2012년도 제7차)(2012.4.13).hwp', '금융통화위원회 의사록(2012년도 제9차)(2012.5.10).hwp', '금융통화위원회 의사록(2013년도 제11차)(2013.6.13).hwp', '금융통화위원회 의사록(2013년도 제12차)(2013.6.27).hwp', '금융통화위원회 의사록(2013년도 제13차)(2013.7.11).hwp', '금융통화위원회 의사록(2013년도 제14차)(2013.7.25).hwp', '금융통화위원회 의사록(2013년도 제15차)(2013.8.8).hwp', '금융통화위원회 의사록(2013년도 제17차)(2013.9.12).hwp', '금융통화위원회 의사록(2013년도 제18차)(2013.9.26.).hwp', '금융통화위원회 의사록(2013년도 
원회 의사록(2015년도 제21차)(2015.11.12.).hwp', '금융통화위원회 의사록(2015년도 제22차)(2015.11.26.).hwp', '금융통화위원회 의사록(2015년도 제23차)(2015.12.10.).hwp', '금융통화위원회 의사록(2015년도 제24차)(2015.12.16.).hwp', '금융통화위원회 의사록(2015년도 제25차)(2015.12.24.).hwp', '금융통화위원회 의사록(2015년도 제2차)(2015.1.29.).hwp', '금융통화위원회 의사록(2015년도 제3차)(2015.2.17.).hwp', '금융통화위원회 의사록(2015년도 제5차)(2015.3.12.).hwp', '금융통화위원회 의사록(2015년도 제6차)(2015.3.26.).hwp', '금융통화위원회 의사록(2015년도 제7차)(2015.4.9.).hwp', '금융통화위원회 의사록(2015년도 제8차)(2015.4.23.).hwp', '금융통화위원회 의사록(2015년도 제9차)(2015.5.15.).hwp', '금융통화위원회 의사록(2016년도 제11차)(2016.6.9.).hwp', '금융통화위원회 의사록(2016년도 제12차)(2016.6.23.).hwp', '금융통화위원회 의사록(2016년도 제13차)(2016.7.1.).hwp', '금융통화위원회 의사록(2016년도 제14차)(2016.7.14.).hwp', '금융통화위원회 의사록(2016년도 제16차)(2016.8.11.).hwp', '금융통화위원회 의사록(2016년도 제18차)(2016.9.9.).hwp', '금융통화위원회 의사록(2016년도 제19차)(2016.9.22.).hwp', '금융통화위원회 의사록(2016년도 제1차)(2016.1.14.).hwp', '금융통화위원회 의사록(2016년도 제20차)(2016.10.13.).hwp', '금융통화위원회 의사록(2016년도 제21차)(2016.10.27.).hwp', '금융통화위원회 의사록(2016년도 제22차)(2016.11.11.).hwp', '금융통화위원회 의사록(2016년도 제23차)(2016.11.24.).hwp', '금융통화위원회 의사록(2016년도 제24차)(2016.12.15.).hwp', '금융통화위원회 의사록(2016년도 제25차)(2016.12.21.).hwp', '금융통화위원회 의사록(2016년도 제26차)(2016.12.29.).hwp', '금융통화위원회 의사록(2016년도 제2차)(2016.1.28.).hwp', '금융통화위원회 의사록(2016년도 제3차)(2016.2.16).hwp', '금융통화위원회 의사록(2016년도 제4차)(2016.2.25.).hwp', '금융통화위원회 의사록(2016년도 제5차)(2016.3.10.).hwp', '금융통화위원회 의사록(2016년도 제6차)(2016.3.24.).hwp', '금융통화위원회 의사록(2016년도 제7차)(2016.4.19.).hwp', '금융통화위원회 의사록(2016년도 제9차)(2016.5.13.).hwp', '금융통화위원회 의사록(2017년도 제10차)(2017.5.25.).hwp', '금융통화위원회 의사록(2017년도 제12차)(2017.6.22.).hwp', '금융통화위원회 의사록(2017년도 제13차)(2017.7.13.).hwp', '금융통화위원회 의사록(2017년도 제15차)(2017.8.10.).hwp', '금융통화위원회 의사록(2017년도 제16차)(2017.8.31.).hwp', '금융통화위원회 의사록(2017년도 제18차)(2017.9.2 ...
# 0
# C:\Users\leeso\TIL\Project\BOK_paper\minutes
# 111

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\leeso\TIL\Project\BOK_paper
