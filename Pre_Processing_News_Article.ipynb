# %%
import pandas as pd
import re

# %%
# 기존 date -> new_date (년-월-일로 포맷 변경된 상태의 csv read()) by y-eon
df_origin = pd.read_csv('naver_interest_article_date.csv')

# %%
df_origin
# Out:
#        journal_name                                      title  \
# 0              이데일리           [마켓in]환율 상승폭 제한..`중공업 네고+ECB 관망`
# 1              이데일리                      (亞증시 오전)中 긴축여파 대부분 하락
# 2              이데일리         [마켓in]CJ제일제당, 대한통운 인수용 2000억 사채 발행
# 3              이데일리              [마감]코스닥, 7일째 상승..평창株 `웃다 울었다`
# 4              이데일리                 `폭우에 파업까지`..구리값 또 오를까 걱정이네
# ...             ...                                        ...
# 200880         연합뉴스                           美 집값 상승 행진 끝이 없다
# 200881       연합인포맥스  국고30년물 0.8조 3.375% 낙찰…응찰률 379.8%<기재부>(상보)
# 200882       연합인포맥스                     한은, 오는 21일 증권차입 3조원 입찰
# 200883       연합인포맥스                       미 국채가, 생산자물가 상승에도 보합
# 200884       연합인포맥스                     주요국 장기금리 하락세, 국채금리 최저치
#
#                         date  \
# 0        2011.07.07. 오후 1:55
# 1       2011.07.07. 오전 11:28
# 2       2011.07.07. 오후 12:22
# 3        2011.07.07. 오후 3:20
# 4       2011.07.07. 오전 10:32
# ...

# %%
df_oper = df_origin

# %%
df_oper
# Out:
#        journal_name                                      title  \
# 0              이데일리           [마켓in]환율 상승폭 제한..`중공업 네고+ECB 관망`
# 1              이데일리                      (亞증시 오전)中 긴축여파 대부분 하락
# 2              이데일리         [마켓in]CJ제일제당, 대한통운 인수용 2000억 사채 발행
# 3              이데일리              [마감]코스닥, 7일째 상승..평창株 `웃다 울었다`
# 4              이데일리                 `폭우에 파업까지`..구리값 또 오를까 걱정이네
# ...             ...                                        ...
# 200880         연합뉴스                           美 집값 상승 행진 끝이 없다
# 200881       연합인포맥스  국고30년물 0.8조 3.375% 낙찰…응찰률 379.8%<기재부>(상보)
# 200882       연합인포맥스                     한은, 오는 21일 증권차입 3조원 입찰
# 200883       연합인포맥스                       미 국채가, 생산자물가 상승에도 보합
# 200884       연합인포맥스                     주요국 장기금리 하락세, 국채금리 최저치
#
#                         date  \
# 0        2011.07.07. 오후 1:55
# 1       2011.07.07. 오전 11:28
# 2       2011.07.07. 오후 12:22
# 3        2011.07.07. 오후 3:20
# 4       2011.07.07. 오전 10:32
# ...

# %%
# new_date 기준으로 axis=0 오름차순 정렬
df_oper = df_oper.sort_values(by=['new_date'], axis=0)
df_oper
# Out:
#        journal_name                               title                  date  \
# 200688         이데일리          은행 `팔고보자`식 단기실적주의 "제무덤 판다"  2005.05.01. 오후 12:31
# 200689         이데일리                  뉴욕증시, FOMC·고용지표 촉각   2005.05.01. 오후 1:10
# 200690         연합뉴스       3월 中企 연체율 2.6%..작년말보다 0.5%p상승   2005.05.01. 오전 8:36
# 200691         연합뉴스              <은행전쟁 원년 `빅4' 1분기 승패는>   2005.05.01. 오전 6:18
# 200695         이데일리                  증시 갈림길..FOMC에 쏠린 눈   2005.05.01. 오전 9:06
# ...             ...                                 ...                   ...
# 404            이데일리            새해 재테크 3대 변수… ‘금리·환율·주가’   2017.12.31. 오후 4:19
# 146            이데일리                 [전문]이주열 한국은행 총재 신년사  2017.12.31. 오후 12:01
# 403            연합뉴스        한은 "글로벌 빅4 성장 양호…미 금리 3회 인상"  2017.12.31. 오후 12:00
# 401            연합뉴스  [신년사] 이주열 한은총재 "금리인상 신중판단…개혁 골든타임"  2017.12.31. 오후 12:00
# 389          연합인포맥스    김태영 은행연합회장 "금리인상기 은행 자산건전성 강화해야"   승인 2017.12.31 10:50
#
# ...

# %%
del df_oper['date']
df_oper
# Out:
#        journal_name                               title  \
# 200688         이데일리          은행 `팔고보자`식 단기실적주의 "제무덤 판다"
# 200689         이데일리                  뉴욕증시, FOMC·고용지표 촉각
# 200690         연합뉴스       3월 中企 연체율 2.6%..작년말보다 0.5%p상승
# 200691         연합뉴스              <은행전쟁 원년 `빅4' 1분기 승패는>
# 200695         이데일리                  증시 갈림길..FOMC에 쏠린 눈
# ...             ...                                 ...
# 404            이데일리            새해 재테크 3대 변수… ‘금리·환율·주가’
# 146            이데일리                 [전문]이주열 한국은행 총재 신년사
# 403            연합뉴스        한은 "글로벌 빅4 성장 양호…미 금리 3회 인상"
# 401            연합뉴스  [신년사] 이주열 한은총재 "금리인상 신중판단…개혁 골든타임"
# 389          연합인포맥스    김태영 은행연합회장 "금리인상기 은행 자산건전성 강화해야"
#
#                                                   article    new_date
# 200688  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...  2005-05-01
# 200689  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[뉴욕=ed...  2005-05-01
# 200690  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t작년동기.전...  2005-05-01
# ...

# %%
replacer = lambda x: str(x).replace('[', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace(']', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('\\n', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('\\t', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('\'', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace(',', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('\\r', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(서울=연합뉴스)', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(서울=연합인포맥스)', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('Copyrightⓒ 2000-2005 edaily. All rights reserved.', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('◆', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('   ', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(끝)', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('◇', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

replacer = lambda x: str(x).replace('  ', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('◇', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

replacer = lambda x: str(x).replace('☎', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

replacer = lambda x: str(x).replace('▲', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('■', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('☞', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: re.sub("\(([\w]+@[\w]+\..+)\)", "", str(x))
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: re.sub("[\w]+@[\w]+\..+", "", str(x))
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace(' edaily ', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('  ', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('`', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace(' (뉴욕=연합뉴스) ', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace(' . ', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace(' 뉴욕=edaily ', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('△', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('" ', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('"', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('뉴욕특파원', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('기자', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('▣', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('▷', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(더 자세한 시황은유료뉴스인 마켓플러스에 게재됐습니다.)', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('특파원', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(뉴욕=연합뉴스)', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(더 자세한 시황은 이데일리 유료뉴스인 마켓플러스에 게재됩니다.)', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('□', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(홍콩=연합뉴스)', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace(' = ', ' ')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('( )', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('=연합뉴스', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('=', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('edaily', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
replacer = lambda x: str(x).replace('(jinhee.', '')
df_oper['article'] = df_oper['article'].map(replacer)

# %%
def article_replace(target, modified=''):
    replacer = lambda x: str(x).replace(target, modified)
    df_oper['article'] = df_oper['article'].map(replacer)

# %%
article_replace('  ', ' ')

# %%
for i in range(1001, 2000):
    print('article No.', i)
    print(df_oper['article'].iloc[i])
    print('')
    print('')
# Out:
# article No. 1001
# 김춘동 대우증권은 오는 17일(금)부터 21일(화)까지 업계 최초로 환율연계 파생결합증권을 판매한다고 14일 밝혔다. 파생결합증권은 지난 3월 증권거래법 시행령 개정에 따라 도입된 신종상품으로 환율이나 금리 실물자산과 연관된 장외파생상품을 기초자산으로 하고 있다. 이번에 판매되는 원/달러 환율 넉아웃형 파생결합증권은 6개월 만기 원금보장형 상품으로 원/달러 환율이 6% 범위 내에서 하락할 경우 최대 연 11.4%의 수익을 제공한다. 한번이라도 6%를 초과해 하락하면 연 4%의 수익을 확정 지급한다. 원/달러 환율 넉아웃형 파생결합증권의 공모금액은 총 200억원 규모며 100만원부터 100만원 단위로 청약이 가능하다. 이제성 대우증권 상품개발마케팅부 부장은 환율연계 파생결합증권은 중국 위안화의 절상 가능성이 높아지면서 원/달러 환율이 5%내외까지 하락할 것이라는 통화 전문가들의 전망에 맞춰 구조화된 상품이라고 소개했다. 이어 파생결합증권은 이번에 첫 선을 보이는 상품인 만큼 안정성에 무게를 두고 원금보장형으로 설계했다며 향후 금 원유 금리 등 실물자산을 연계하는 다양한 파생결합증권을 개발하겠다고 설명했다.문의전화: 1588-3322 김춘동
#
#
# article No. 1002
# ...

# %%
df_oper
# Out:
#        journal_name                               title  \
# 200688         이데일리          은행 `팔고보자`식 단기실적주의 "제무덤 판다"
# 200689         이데일리                  뉴욕증시, FOMC·고용지표 촉각
# 200690         연합뉴스       3월 中企 연체율 2.6%..작년말보다 0.5%p상승
# 200691         연합뉴스              <은행전쟁 원년 `빅4' 1분기 승패는>
# 200695         이데일리                  증시 갈림길..FOMC에 쏠린 눈
# ...             ...                                 ...
# 404            이데일리            새해 재테크 3대 변수… ‘금리·환율·주가’
# 146            이데일리                 [전문]이주열 한국은행 총재 신년사
# 403            연합뉴스        한은 "글로벌 빅4 성장 양호…미 금리 3회 인상"
# 401            연합뉴스  [신년사] 이주열 한은총재 "금리인상 신중판단…개혁 골든타임"
# 389          연합인포맥스    김태영 은행연합회장 "금리인상기 은행 자산건전성 강화해야"
#
#                                                   article    new_date
# 200688  오상용 은행들이 수수료 수입에 급급한 나머지 일단 팔고 보자는 식의 상품판매 경쟁에...  2005-05-01
# 200689  안근모 뉴욕증시 투자자들이 시장의 방향을 정하지 못한채 하루하루 재료에 과민반응하고...  2005-05-01
# 200690   작년동기.전월 대비로는 0.2%p 낮아 박성제 3월 중소기업 대출 연체율이 작년 ...  2005-05-01
# ...

# %%
# new_date column 위치 변경
df_oper = df_oper[['journal_name', 'new_date','title', 'article']]

# %%
df_oper
# Out:
#        journal_name    new_date                               title  \
# 200688         이데일리  2005-05-01          은행 `팔고보자`식 단기실적주의 "제무덤 판다"
# 200689         이데일리  2005-05-01                  뉴욕증시, FOMC·고용지표 촉각
# 200690         연합뉴스  2005-05-01       3월 中企 연체율 2.6%..작년말보다 0.5%p상승
# 200691         연합뉴스  2005-05-01              <은행전쟁 원년 `빅4' 1분기 승패는>
# 200695         이데일리  2005-05-01                  증시 갈림길..FOMC에 쏠린 눈
# ...             ...         ...                                 ...
# 404            이데일리  2017-12-31            새해 재테크 3대 변수… ‘금리·환율·주가’
# 146            이데일리  2017-12-31                 [전문]이주열 한국은행 총재 신년사
# 403            연합뉴스  2017-12-31        한은 "글로벌 빅4 성장 양호…미 금리 3회 인상"
# 401            연합뉴스  2017-12-31  [신년사] 이주열 한은총재 "금리인상 신중판단…개혁 골든타임"
# 389          연합인포맥스  2017-12-31    김태영 은행연합회장 "금리인상기 은행 자산건전성 강화해야"
#
#                                                   article
# 200688  오상용 은행들이 수수료 수입에 급급한 나머지 일단 팔고 보자는 식의 상품판매 경쟁에...
# ...

# %%
# new_date column 이름 date로 변경
df_oper = df_oper.rename(columns={'new_date': 'date'})
df_oper
# Out:
#        journal_name        date                               title  \
# 200688         이데일리  2005-05-01          은행 `팔고보자`식 단기실적주의 "제무덤 판다"
# 200689         이데일리  2005-05-01                  뉴욕증시, FOMC·고용지표 촉각
# 200690         연합뉴스  2005-05-01       3월 中企 연체율 2.6%..작년말보다 0.5%p상승
# 200691         연합뉴스  2005-05-01              <은행전쟁 원년 `빅4' 1분기 승패는>
# 200695         이데일리  2005-05-01                  증시 갈림길..FOMC에 쏠린 눈
# ...             ...         ...                                 ...
# 404            이데일리  2017-12-31            새해 재테크 3대 변수… ‘금리·환율·주가’
# 146            이데일리  2017-12-31                 [전문]이주열 한국은행 총재 신년사
# 403            연합뉴스  2017-12-31        한은 "글로벌 빅4 성장 양호…미 금리 3회 인상"
# 401            연합뉴스  2017-12-31  [신년사] 이주열 한은총재 "금리인상 신중판단…개혁 골든타임"
# 389          연합인포맥스  2017-12-31    김태영 은행연합회장 "금리인상기 은행 자산건전성 강화해야"
#
#                                                   article
# 200688  오상용 은행들이 수수료 수입에 급급한 나머지 일단 팔고 보자는 식의 상품판매 경쟁에...
# ...

# %%
# 전처리가 끝난 dataframe 저장
df_oper.to_csv('pre_processed_naver_interest_article.csv', index = False)

# %%
# 저장된 dataframe 확인
df_ = pd.read_csv('pre_processed_naver_interest_article.csv')
df_
# Out:
#        journal_name        date                               title  \
# 0              이데일리  2005-05-01          은행 `팔고보자`식 단기실적주의 "제무덤 판다"
# 1              이데일리  2005-05-01                  뉴욕증시, FOMC·고용지표 촉각
# 2              연합뉴스  2005-05-01       3월 中企 연체율 2.6%..작년말보다 0.5%p상승
# 3              연합뉴스  2005-05-01              <은행전쟁 원년 `빅4' 1분기 승패는>
# 4              이데일리  2005-05-01                  증시 갈림길..FOMC에 쏠린 눈
# ...             ...         ...                                 ...
# 200880         이데일리  2017-12-31            새해 재테크 3대 변수… ‘금리·환율·주가’
# 200881         이데일리  2017-12-31                 [전문]이주열 한국은행 총재 신년사
# 200882         연합뉴스  2017-12-31        한은 "글로벌 빅4 성장 양호…미 금리 3회 인상"
# 200883         연합뉴스  2017-12-31  [신년사] 이주열 한은총재 "금리인상 신중판단…개혁 골든타임"
# 200884       연합인포맥스  2017-12-31    김태영 은행연합회장 "금리인상기 은행 자산건전성 강화해야"
#
#                                                   article
# 0       오상용 은행들이 수수료 수입에 급급한 나머지 일단 팔고 보자는 식의 상품판매 경쟁에...
# ...
